# %% [markdown]
# ## Web Scraping Bicycle e-commerce Site

# %% [markdown]
# **Álvaro Rivera Arcelus**<br>
# *Economics + Data Analytics*

# %% [markdown]
# ### About the the company

# %% [markdown]
# **Chain Reaction**<br>
# *   Chain Reaction is a british bycycle online store. They sell all types of bicycles and cycling apparel from more then 100 high and medium quality brands
# *   ***Type of site***: dynamic site
# *   ***URL***: https://www.chainreactioncycles.com/

# %% [markdown]
# ### Scraping methodology

# %% [markdown]
# As the site is a dynamic website (i.e; presence of JavaScript) we are not able to apply conventional packages such as *Beautiful Soup*.<br>
# If we try to do so, we tend to obtain less information than the one that we as users see on our screen. <br>
# This is commonly caused by function that developers implement on sites in order to improve loading times. (JS Lazy Loading)<br><br>
# **Solution:** use *Selenium package* which acts as a "bot" by crawling on the site

# %% [markdown]
# We wil be gathering the following information about their bikes:<br>
# *   Regular price
# *   Sale price
# *   Product description

# %% [markdown]
# **Importing libraries**

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import pandas as pd
import numpy as np

# %% [markdown]
# **Scraping site**

# %%
#creating main df where we'll concatenate the final data
main_df = pd.DataFrame(columns=['name','reg_price','price'])

#function that adds all the scraped items into a single array 
def createArray(elements):
    array =[]
    for element in elements: 
        array.append(element.text)
    return array

#using firefox driver to crawl on site
driver = webdriver.Firefox(executable_path=r'C:\Program Files (x86)\geckodriver.exe')

def addNewBike(url):
    driver.get(url)

    price_elem = driver.find_elements(By.CLASS_NAME, "fromamt")
    reg_price_elem = driver.find_elements(By.CLASS_NAME, "rrpamount")
    name_elem = driver.find_elements(By.CLASS_NAME, "description")

    reg_price = createArray(reg_price_elem)
    price = createArray(price_elem)
    name = createArray(name_elem)

    #in case the last bikes didn't have a discount, we need to make all arrays the same length
    #we add a "none" string to missing data
    if len(price)>len(reg_price):
        n = abs(len(price)-len(reg_price))
        #adding to null values a zero
        reg_price = np.concatenate((reg_price,np.repeat('none',n)), axis=None)

    df = pd.DataFrame()
    df['reg_price'] = reg_price
    df['price'] = price
    df['name'] = name

    #we must explicitly say that the variable is global 
    global main_df
    #concatenating new data to dataframe 
    main_df = pd.concat((main_df, df), axis=0)

    return main_df

#links we want to crawl on 
links = ['https://www.chainreactioncycles.com/road-bikes?f=2231&sort=discount', 
        'https://www.chainreactioncycles.com/mountain-bikes?f=2232&sort=discount',
        'https://www.chainreactioncycles.com/bmx-bikes?f=2240&sort=discount',
        'https://www.chainreactioncycles.com/folding-bikes?f=2249&sort=discount',
        'https://www.chainreactioncycles.com/hybrid-city-bikes?f=2234&sort=discount']

#scrapping and concatenating all the data in all the required links at once 
for link in links: main_df = addNewBike(link)


driver.quit()
# Out:
# C:\Users\alvar\AppData\Local\Temp\ipykernel_25656\1984935713.py:12: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Firefox(executable_path=r'C:\Program Files (x86)\geckodriver.exe')

# %% [markdown]
# Visualizing results (first 50 rows)

# %%
print('------------'*3)
print('Number of products: '+str(len(main_df)))
print('------------'*3)
# Out:
# ------------------------------------
# Number of products: 196
# ------------------------------------

# %%
main_df.reset_index().head(50)
# Out:
#     index                                             name     reg_price  \
# 0       0                  Fuji Sportif 2.3 Road Bike 2022   RRP £849.99
# 1       1                  Fuji Sportif 2.1 Road Bike 2022  RRP £1049.99
# 2       2               Fuji Gran Fondo 1.1 Road Bike 2021  RRP £3399.99
# 3       3               Fuji Gran Fondo 1.3 Road Bike 2021  RRP £2599.99
# 4       4                 Rondo RUUT AL 1 Gravel Bike 2022  RRP £2199.99
# 5       5                 Rondo RUUT AL 2 Gravel Bike 2022  RRP £1799.99
# 6       6             Kona Rove AL 650 SE Gravel Bike 2022   RRP £999.99
# 7       7     Vitus ZX-1 EVO CR eTap AXS Road Bike (Rival)  RRP £3899.99
# 8       8      Octane One Kode ADV Commuter Road Bike 2022  RRP £1139.99
# 9       9                Cube Axial WS Race Road Bike 2022  RRP £1748.99
# 10     10                     Cube Axial WS Road Bike 2022   RRP £948.99
# 11     11                   Rondo HVRT CF 0 Road Bike 2021  RRP £6799.99
# 12     12                       FIXIE Inc. Floater Race 8S   RRP £439.99
# 13     13           FIXIE Inc. Floater Race 8S Disc Street   RRP £519.99
# 14     14      Vitus ZX-1 EVO CRX eTap AXS Road Bike (Red)  RRP £5999.99
# 15     15                              Ortler Sven 7 Speed   RRP £599.99
# 16     16       Vitus Vitesse EVO CR eTap AXS Road (Rival)  RRP £3599.99
# 17     17  Orro Venturi STC Rival eTap R800 Road Bike 2021  RRP £3499.99
# 18     18   Vitus Vitesse EVO CRX eTap AXS Road Bike (Red)  RRP £5499.99
# 19     19                                Brand-X Road Bike   RRP £349.99
# 20     20          Cinelli Pressure Disc Ultegra Bike 2022  RRP £3798.99
# 21     21    Vitus ZX-1 EVO CRS eTap AXS Road Bike (Force)  RRP £4799.99
# 22     22                 Vitus Razor W Road Bike (Claris)   RRP £599.99
# 23     23           Vitus Razor FB Disc Road Bike (Claris)   RRP £699.99
# 24     24          Cinelli Veltrix Disc 105 Road Bike 2022  RRP £2298.99
# 25     25                    Cube Attain SL Road Bike 2022  RRP £1748.99
# 26     26      Vitus Vitesse EVO CRS eTap AXS Road (Force)  RRP £4399.99
# 27     27                Kona Sutra SE Adventure Bike 2022  RRP £1649.99
# 28     28    Ridley Helium SLX Disc Ultegra Road Bike 2022  RRP £4298.99
# 29     29             Vitus Zenium CRS Road Bike (Ultegra)  RRP £1999.99
# 30     30             Vitus Razor VR Disc Road Bike (Sora)   RRP £799.99
# 31     31                  Vitus Zenium Road Bike (Tiagra)  RRP £1199.99
# 32     32           Vitus ZX-1 EVO CRS Road Bike (Ultegra)  RRP £3499.99
# 33     33                  Vitus Zenium CR Road Bike (105)  RRP £1599.99
# 34     34               Vitus Zenium FB Road Bike (Tiagra)  RRP £1199.99
# 35     35                 Vitus Zenium CRW Road Bike (105)  RRP £1599.99
# 36     36       Vitus ZX-1 EVO CRS Di2 Road Bike (Ultegra)  RRP £4599.99
# 37     37              Vitus Razor Disc Road Bike (Claris)   RRP £699.99
# 38     38                   Vitus Razor Road Bike (Claris)   RRP £599.99
# 39     39    Vitus Vitesse EVO CRS Di2 Road Bike (Ultegra)  RRP £4199.99
# 40     40            Vitus Razor W Disc Road Bike (Claris)   RRP £699.99
# 41     41                       Cube Attain Road Bike 2022   RRP £948.99
# 42     42                   Cube Attain Pro Road Bike 2022  RRP £1048.99
# 43     43                    Cube Agree C62 Road Bike 2022  RRP £3098.99
# 44     44               Cube Agree C62 Race Road Bike 2022  RRP £4098.99
# 45     45               Ridley Liz SL D 105 Road Bike 2021          none
# 46     46               Cube Nuroad C62 Pro Road Bike 2022          none
# 47     47   Orro Gold STC Rival eTap R800DB Road Bike 2022          none
# 48      0            Fuji Nevada 29 1.9 Hardtail Bike 2022   RRP £599.99
# 49      1          Fuji Nevada 27.5 1.9 Hardtail Bike 2022   RRP £599.99
#
#                   price
# 0               £424.99
# 1               £524.99
# 2              £1699.99
# 3              £1299.99
# 4   £1199.99 - £1429.99
# 5               £999.99
# 6               £649.99
# 7              £2729.99
# 8               £799.99
# 9              £1299.99
# 10    £699.99 - £799.99
# 11             £4999.99
# 12              £329.99
# 13              £389.99
# 14             £4499.99
# 15              £449.99
# 16             £2699.99
# 17             £2699.99
# 18             £4399.99
# 19              £279.99
# 20             £3039.99
# 21             £3849.99
# 22              £479.99
# 23              £559.99
# 24  £1839.99 - £1999.99
# 25             £1449.99
# 26             £3739.99
# 27             £1399.99
# 28             £3869.99
# 29             £1799.99
# 30              £722.99
# 31             £1079.99
# 32             £3149.99
# 33             £1439.99
# 34             £1079.99
# 35             £1439.99
# 36             £4139.99
# 37              £629.99
# 38              £539.99
# 39             £3779.99
# 40              £629.99
# 41              £899.99
# 42              £999.99
# 43  £2999.99 - £3098.99
# 44             £3999.99
# 45             £1898.99
# 46             £2498.99
# 47             £3399.99
# 48              £259.99
# 49              £259.99
